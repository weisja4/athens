# %%
import requests
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings("ignore") # Shhhh
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression 
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
import seaborn as sns
from sklearn.linear_model import Ridge, Lasso, LassoCV
from sklearn.linear_model import RidgeCV
from sklearn.dummy import DummyRegressor

# %%
url = "https://qpublic.schneidercorp.com/Application.aspx?AppID=630&LayerID=11199&PageTypeID=4&PageID=4601&Q=189082873&KeyValue=032a1+a004"
res = requests.get(url)
res.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(res.content, 'lxml')

# %%
parcels = pd.read_csv('../data/parcels.csv')

# %%
type(parcels)
# Out:
# pandas.core.frame.DataFrame

# %%
parcels = parcels.values.tolist()

# %%
list = []
for items in parcels:
    for item in items:
        list.append(item)
list
# Out:
# ['012    002',
#  '012    002A',
#  '012    003',
#  '012    003A',
#  '012    003B',
#  '012    003C',
#  '012    004',
#  '012    004A',
#  '012    004B',
#  '012    004C',
#  '012    004D',
#  '012    004E         ',
#  '012    004F',
#  '012    005          ',
#  '012    005A',
#  '012    005B',
#  '012    008          ',
#  '012A   001',
#  '012A   002',
#  '012A   003',
#  '012A   004',
#  '012A   005',
#  '012A   006',
#  '012A   006A         ',
#  '012A   007',
#  '012A   008',
#  '012A   009',
#  '024    001          ',
#  '024    002',
#  '024    003',
#  '024    004',
#  '024    005          ',
#  '024    006          ',
#  '024    007          ',
#  '024    008          ',
#  '024    008A',
#  '024    009',
#  '024    009A',
#  '024    010          ',
#  '024    011          ',
#  '024    012',
#  '024    012A         ',
#  '024    012B         ',
#  '024    012C         ',
#  '024    012D',
#  '024    012E',
#  '024    012F         ',
#  '024    012G         ',
# ...

# %%
parcel_list = []
for parcel in list:
    parc = parcel.strip()
    parcel_list.append(parc)

# %%
parcels = []
for parcel in parcel_list:
    split = parcel.split()
    new = ""
    for item in split:
        new += item + " "
    new = new.strip()
    parcels.append(new)

# %%
parcels
# Out:
# ['012 002',
#  '012 002A',
#  '012 003',
#  '012 003A',
#  '012 003B',
#  '012 003C',
#  '012 004',
#  '012 004A',
#  '012 004B',
#  '012 004C',
#  '012 004D',
#  '012 004E',
#  '012 004F',
#  '012 005',
#  '012 005A',
#  '012 005B',
#  '012 008',
#  '012A 001',
#  '012A 002',
#  '012A 003',
#  '012A 004',
#  '012A 005',
#  '012A 006',
#  '012A 006A',
#  '012A 007',
#  '012A 008',
#  '012A 009',
#  '024 001',
#  '024 002',
#  '024 003',
#  '024 004',
#  '024 005',
#  '024 006',
#  '024 007',
#  '024 008',
#  '024 008A',
#  '024 009',
#  '024 009A',
#  '024 010',
#  '024 011',
#  '024 012',
#  '024 012A',
#  '024 012B',
#  '024 012C',
#  '024 012D',
#  '024 012E',
#  '024 012F',
#  '024 012G',
#  '024 012H',
#  '024 012J',
#  '024 012K',
#  '024 013',
#  '031 001',
#  '032 001',
#  '032 001A',
#  '032 001B',
#  '032 001C',
#  '032 001D',
#  '032 001E',
#  '032 002',
#  '032 002A',
#  '032 002B',
#  '032 002C',
#  '032 005',
#  '032 005A',
#  '032 005B',
#  '032 005C',
#  '032 005D',
# ...

# %%
test= parcel_list[3]
list
# Out:
# '012    003A'

# %%
test_list = list.split()

# %%
tester = ""
for list in test_list:
    tester += list +" "

# %%
tester
# Out:
# '012 003A '

# %%
tester.strip()
# Out:
# '012 003A'
